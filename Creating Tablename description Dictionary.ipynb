# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
# %config IPCompleter.greedy=True
engine = create_engine("mysql+mysqlconnector://root:root@localhost/ds_db_schema?host=localhost?port=3306")
print(engine.table_names())
# Out:
# ['2016census_g01_sa_poa', '2016census_g02_sa_poa', '2016census_g03_sa_poa', '2016census_g04a_sa_poa', '2016census_g04b_sa_poa', '2016census_g05_sa_poa', '2016census_g06_sa_poa', '2016census_g07_sa_poa', '2016census_g08_sa_poa', '2016census_g09a_sa_poa', '2016census_g09b_sa_poa', '2016census_g09c_sa_poa', '2016census_g09d_sa_poa', '2016census_g09e_sa_poa', '2016census_g09f_sa_poa', '2016census_g09g_sa_poa', '2016census_g09h_sa_poa', '2016census_g10a_sa_poa', '2016census_g10b_sa_poa', '2016census_g10c_sa_poa', '2016census_g11a_sa_poa', '2016census_g11b_sa_poa', '2016census_g11c_sa_poa', '2016census_g11d_sa_poa', '2016census_g12a_sa_poa', '2016census_g12b_sa_poa', '2016census_g13a_sa_poa', '2016census_g13b_sa_poa', '2016census_g13c_sa_poa', '2016census_g13d_sa_poa', '2016census_g14_sa_poa', '2016census_g15_sa_poa', '2016census_g16a_sa_poa', '2016census_g16b_sa_poa', '2016census_g17a_sa_poa', '2016census_g17b_sa_poa', '2016census_g17c_sa_poa', '2016census_g18_sa_poa', '2016census_g19_sa_
# ...

# %%
import os
df_filedescrip = pd.read_csv('C:\\Users\Arjun\Desktop\poa\Metadata\\tablenames.csv')

# %%
df_filedescrip.head(5)
# Out:
#   Table number                                       Table name
# 0          G01           Selected Person Characteristics by Sex
# 1          G02                    Selected Medians and Averages
# 2          G03  Place of Usual Residence on Census Night by Age
# 3         G04A                                       Age by Sex
# 4         G04B                                       Age by Sex

# %%
a= engine.table_names()
dicti=list()
for i in range(len(a)):
    dicti.append([a[i], df_filedescrip['Table name'][i]])

# %%
dicti
# Out:
# [['2016census_g01_sa_poa', 'Selected Person Characteristics by Sex'],
#  ['2016census_g02_sa_poa', 'Selected Medians and Averages'],
#  ['2016census_g03_sa_poa', 'Place of Usual Residence on Census Night by Age'],
#  ['2016census_g04a_sa_poa', 'Age by Sex'],
#  ['2016census_g04b_sa_poa', 'Age by Sex'],
#  ['2016census_g05_sa_poa', 'Registered Marital Status by Age by Sex'],
#  ['2016census_g06_sa_poa', 'Social Marital Status by Age by Sex'],
#  ['2016census_g07_sa_poa', 'Indigenous Status by Age by Sex '],
#  ['2016census_g08_sa_poa', 'Ancestry by Country of Birth of Parents'],
#  ['2016census_g09a_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09b_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09c_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09d_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09e_sa_poa', 'Country of Birth of Person by Age by Sex'],
# ...

# %%
import json
with open('C:\\Users\Arjun\Desktop\poa\Output_Table_names.txt','w') as f:
    json.dump(dicti, f)

# %%
import json

# %%
with open('tables\Output_Table_names.txt','r') as f:
    myDictLoaded = json.load(f)

# %%
myDictLoaded
# Out:
# [['2016census_g01_sa_poa', 'Selected Person Characteristics by Sex'],
#  ['2016census_g02_sa_poa', 'Selected Medians and Averages'],
#  ['2016census_g03_sa_poa', 'Place of Usual Residence on Census Night by Age'],
#  ['2016census_g04a_sa_poa', 'Age by Sex'],
#  ['2016census_g04b_sa_poa', 'Age by Sex'],
#  ['2016census_g05_sa_poa', 'Registered Marital Status by Age by Sex'],
#  ['2016census_g06_sa_poa', 'Social Marital Status by Age by Sex'],
#  ['2016census_g07_sa_poa', 'Indigenous Status by Age by Sex '],
#  ['2016census_g08_sa_poa', 'Ancestry by Country of Birth of Parents'],
#  ['2016census_g09a_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09b_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09c_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09d_sa_poa', 'Country of Birth of Person by Age by Sex'],
#  ['2016census_g09e_sa_poa', 'Country of Birth of Person by Age by Sex'],
# ...
